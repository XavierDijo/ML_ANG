# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ('ex1data1.txt', sep=",", header=None)

# %%
X = df.values[:,0:1] 
y = df.values[:,1:2]

# %%
X = np.insert(X, 0, 1, axis=1) #Add column "1"

# %% [markdown]
# # Cost Function

# %%
def computeCost(X,y,theta):
    m=len(y)
    return np.sum(np.square(X.dot(theta) - y))/(2*m)

# %% [markdown]
# # Gradient Descent

# %%
def gradientDescent(X, y, theta, alpha, num_iters) :
    m=len(y)
    J_history=[]
    
    for i in range(num_iters):
        theta = theta - (alpha * 1/m) * np.dot(X.transpose(),(X.dot(theta) -y))
        J_history.append(computeCost(X,y,theta))
    
    return theta, J_history

# %%
theta = np.array([[0,],[0,]])
theta,J_history = gradientDescent(X,y,theta,0.02,1500)

# %%
import matplotlib.pyplot as plt
plt.plot(J_history)
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.title("Gradient Descent")
# Out:
# Text(0.5, 1.0, 'Gradient Descent')

# %%
theta
# Out:
# array([[-3.87813769],
#        [ 1.19126119]])

# %%
plt.scatter(df.values[:,0:1],y)


x_value=[x for x in range(25)]
y_value=[y*theta[1]+theta[0] for y in x_value]
plt.plot(x_value,y_value,color="r")
plt.xlabel("Population of City")
plt.ylabel("Profit")
plt.title("Linear regression fit")
# Out:
# Text(0.5, 1.0, 'Linear regression fit')

# %% [markdown]
# # Normal Equations

# %%
from numpy.linalg import inv

# %%
# normal equation  
# theta_best = (X.T * X)^(-1) * X.T * y

# %%
X_transpose = X.T  
theta_best = inv(X_transpose.dot(X)).dot(X_transpose).dot(y)

# %%
theta_best
# Out:
# array([[-3.89578088],
#        [ 1.19303364]])

# %%
plt.scatter(df.values[:,0:1],y)


x_value=[x for x in range(25)]
y_value=[y*theta_best[1]+theta_best[0] for y in x_value]
plt.plot(x_value,y_value,color="g", label ="normal equation")



x_value=[x for x in range(25)]
y_value=[y*theta[1]+theta[0] for y in x_value]
plt.plot(x_value,y_value,color="r", label="GD")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Line plot using GD and Normal equation")

# %% [markdown]
# # Linear regression with multiple variables

# %%
df2 = pd.read_csv ('ex1data2.txt', sep=",", header=None)

# %%
X2 = df2.values[:,0:2]
y2 = df2.values[:,2:3]

# %%
mean=np.mean(X2,axis=0)
std=np.std(X2,axis=0)
    
X_norm = (X2 - mean)/std

# %%
mean=np.mean(y2,axis=0)
std=np.std(y2,axis=0)
    
y_norm = (y2 - mean)/std

# %%
X_norm = np.insert(X_norm, 0, 1, axis=1)

# %%
theta2 = np.array([[0,],[0,],[0,]])
theta2,J_history = gradientDescent(X_norm,y_norm,theta2,0.01,1500)

# %%
theta2
# Out:
# array([[-8.30541309e-17],
#        [ 8.84137547e-01],
#        [-5.25503786e-02]])

# %%
import matplotlib.pyplot as plt
plt.plot(J_history)
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.title("Gradient Descent")
# Out:
# Text(0.5, 1.0, 'Gradient Descent')

# %%
X_transpose = X_norm.T  
theta_best = inv(X_transpose.dot(X_norm)).dot(X_transpose).dot(y_norm)

# %%
theta_best
# Out:
# array([[-4.16333634e-17],
#        [ 8.84765988e-01],
#        [-5.31788197e-02]])
